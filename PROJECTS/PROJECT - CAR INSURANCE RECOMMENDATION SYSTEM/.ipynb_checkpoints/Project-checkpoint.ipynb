# %% [markdown]
# # MY 1st Project
# # Car Insurance Recommender System

# %%
import numpy as np 
import pandas as pd

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# %matplotlib inline

# %%
df=pd.read_csv("final_df.csv")

# %%
df.head()
# Out:
#    company                     Model name    year    fuel        owner  seats  \
# 0   Maruti         Maruti Swift Dzire VDI  2014.0  Diesel  First Owner    5.0
# 1    Honda       Honda City 2017-2020 EXi  2006.0  Petrol  Third Owner    5.0
# 2  Hyundai      Hyundai i20 Sportz Diesel  2010.0  Diesel  First Owner    5.0
# 3   Maruti         Maruti Swift VXI BSIII  2007.0  Petrol  First Owner    5.0
# 4  Hyundai  Hyundai Xcent 1.2 VTVT E Plus  2017.0  Petrol  First Owner    5.0
#
#     engine  selling_price seller_type  km_driven     mileage   max_power  \
# 0  1248 CC       450000.0  Individual   145500.0   23.4 kmpl      74 bhp
# 1  1498 CC       370000.0  Individual   120000.0  21.14 kmpl  103.52 bhp
# 2  1497 CC       158000.0  Individual   140000.0   17.7 kmpl      78 bhp
# 3  1396 CC       225000.0  Individual   127000.0   23.0 kmpl      90 bhp
# 4  1298 CC       130000.0  Individual   120000.0   16.1 kmpl    88.2 bhp
#
#                      torque                                       Insurance
# 0            190Nm@ 2000rpm  Comapany Name:ICICI Lombord,Policy Plan:2000000
# 1       250Nm@ 1500-2500rpm  Comapany Name:ICICI Lombord,Policy Plan:2000000
# 2     12.7@ 2,700(kgm@ rpm)  Comapany Name:ICICI Lombord,Policy Plan:2000000
# 3  22.4 kgm at 1750-2750rpm  Comapany Name:ICICI Lombord,Policy Plan:2000000
# 4     11.5@ 4,500(kgm@ rpm)  Comapany Name:ICICI Lombord,Policy Plan:2000000

# %%
df.drop(['year','selling_price','seller_type','km_driven','mileage','max_power','torque','owner'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    company                     Model name    fuel  seats   engine  \
# 0   Maruti         Maruti Swift Dzire VDI  Diesel    5.0  1248 CC
# 1    Honda       Honda City 2017-2020 EXi  Petrol    5.0  1498 CC
# 2  Hyundai      Hyundai i20 Sportz Diesel  Diesel    5.0  1497 CC
# 3   Maruti         Maruti Swift VXI BSIII  Petrol    5.0  1396 CC
# 4  Hyundai  Hyundai Xcent 1.2 VTVT E Plus  Petrol    5.0  1298 CC
#
#                                         Insurance
# 0  Comapany Name:ICICI Lombord,Policy Plan:2000000
# 1  Comapany Name:ICICI Lombord,Policy Plan:2000000
# 2  Comapany Name:ICICI Lombord,Policy Plan:2000000
# 3  Comapany Name:ICICI Lombord,Policy Plan:2000000
# 4  Comapany Name:ICICI Lombord,Policy Plan:2000000

# %%
df['fuel'] = df['fuel'].apply(lambda x:x.lower())

# %%
df.head()
# Out:
#    company                     Model name    fuel  seats  new engine  \
# 0   Maruti         Maruti Swift Dzire VDI  diesel    5.0        1248
# 1    Honda       Honda City 2017-2020 EXi  petrol    5.0        1497
# 2  Hyundai      Hyundai i20 Sportz Diesel  diesel    5.0        1396
# 3   Maruti         Maruti Swift VXI BSIII  petrol    5.0        1298
# 4  Hyundai  Hyundai Xcent 1.2 VTVT E Plus  petrol    5.0        1197
#
#                                     Insurance Plan  \
# 0  Comapany Name:ICICI Lombord,Policy Plan:2000000
# 1  Comapany Name:ICICI Lombord,Policy Plan:2000000
# 2  Comapany Name:ICICI Lombord,Policy Plan:2000000
# 3  Comapany Name:ICICI Lombord,Policy Plan:2000000
# 4  Comapany Name:ICICI Lombord,Policy Plan:2000000
#
#                                           feature  Insurance_id  \
# 0          maruti maruti swift dzire vdi 5.0 1248            11
# 1         honda honda city 2017-2020 exi 5.0 1497            11
# 2      hyundai hyundai i20 sportz diesel 5.0 1396            11
# 3          maruti maruti swift vxi bsiii 5.0 1298            11
# 4  hyundai hyundai xcent 1.2 vtvt e plus 5.0 1197            11
#
#                                          Insurance
# 0  Comapany Name:ICICI Lombord,Policy Plan:2000000
# 1  Comapany Name:ICICI Lombord,Policy Plan:2000000
# 2  Comapany Name:ICICI Lombord,Policy Plan:2000000
# 3  Comapany Name:ICICI Lombord,Policy Plan:2000000
# 4  Comapany Name:ICICI Lombord,Policy Plan:2000000

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
cv = CountVectorizer(max_features=7000,stop_words='english')

# %%
vectors=cv.fit_transform(df['feature']).toarray()

# %%
vectors.shape
# Out:
# (7492, 770)

# %%
cv.get_feature_names()
# Out:
# C:\Users\reliance\anaconda3\lib\site-packages\sklearn\utils\deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)
# ['02',
#  '05',
#  '0d',
#  '0l',
#  '10',
#  '100',
#  '1047',
#  '1061',
#  '1086',
#  '110ps',
#  '1120',
#  '1172',
#  '1186',
#  '1193',
#  '1194',
#  '1196',
#  '1197',
#  '1198',
#  '1199',
#  '120',
#  '1248',
#  '1298',
#  '1299',
#  '1339',
#  '1341',
#  '1343',
#  '1364',
#  '1368',
#  '1373',
#  '1388',
#  '1390',
#  '1396',
#  '1399',
#  '14',
#  '1405',
#  '1461',
#  '1462',
#  '1493',
#  '1495',
#  '1496',
#  '1497',
#  '1498',
#  '1499',
#  '1505',
#  '1527',
#  '1582',
#  '1586',
#  '1590',
#  '1591',
#  '1595',
#  '1596',
#  '1597',
#  '1598',
#  '1599',
#  '16',
#  '177',
#  '1781',
#  '1794',
#  '1795',
#  '1796',
#  '1797',
#  '1798',
#  '1799',
#  '1896',
#  '1948',
#  '1950',
#  '1956',
#  '1968',
#  '1969',
#  '1984',
#  '1991',
#  '1995',
#  '1997',
#  '1998',
#  '1999',
#  '1l',
#  '200',
#  '2001',
#  '2006',
#  '2009',
#  '2010',
#  '2011',
#  '2014',
#  '2015',
#  '2016',
#  '2017',
#  '2018',
#  '2019',
#  '2020',
#  '2092',
#  '20d',
#  '2143',
#  '2148',
#  '2179',
#  '2197',
#  '2198',
#  '2199',
#  '220',
#  '220d',
#  '2354',
#  '2359',
#  '2362',
#  '2393',
#  '2446',
#  '2489',
#  '2494',
#  '2497',
#  '2498',
#  '2499',
#  '250',
#  '2523',
#  '2609',
#  '2694',
#  '2696',
#  '2755',
#  '2953',
#  '2956',
#  '2967',
#  '2982',
#  '2987',
#  '2993',
#  '2997',
#  '2l',
#  '2p',
#  '2t',
#  '2wd',
#  '300',
#  '30d',
#  '3198',
#  '320d',
#  '3498',
#  '35',
#  '350',
#  '35tdi',
#  '3b',
#  '3l',
#  '40',
#  '400',
#  '45',
#  '4d',
#  '4l',
#  '4matic',
#  '4wd',
#  '4x2',
#  '4x4',
#  '500',
#  '520d',
#  '523i',
#  '525d',
#  '530d',
#  '540',
#  '550',
#  '5d',
#  '5l',
#  '5p',
#  '5str',
#  '624',
#  '630d',
#  '730ld',
#  '75ps',
#  '793',
#  '796',
#  '799',
#  '7s',
#  '7t',
#  '800',
#  '814',
#  '85ps',
#  '8s',
#  '8str',
#  '90',
#  '909',
#  '90hp',
#  '99',
#  '993',
#  '998',
#  '999',
#  '9s',
#  'a3',
#  'a4',
#  'a6',
#  'abs',
#  'ac',
#  'accent',
#  'accord',
#  'active',
#  'adventure',
#  'ae',
#  'ags',
#  'airbag',
#  'alloy',
#  'alpha',
#  'altis',
#  'alto',
#  'amaze',
#  'ambiente',
#  'ameo',
#  'amt',
#  'anniversary',
#  'aqua',
#  'aria',
#  'aspire',
#  'asta',
#  'audi',
#  'aura',
#  'automatic',
#  'avantgarde',
#  'avantgare',
#  'avantgrade',
#  'avn',
#  'aw',
#  'awd',
#  'ax',
#  'b180',
#  'b2',
#  'b200',
#  'b3',
#  'b4',
#  'baleno',
#  'base',
#  'basic',
#  'benz',
#  'bhp',
#  'bl',
#  'blu',
#  'blue',
#  'bmw',
#  'bolero',
#  'bolt',
#  'br',
#  'breeze',
#  'brezza',
#  'brio',
#  'brv',
#  'bs',
#  'bs4',
#  'bsii',
#  'bsiii',
#  'bsiv',
#  'c1',
#  'c2',
#  'c4',
#  'c6',
#  'c8',
#  'camper',
#  'camry',
#  'captain',
#  'captur',
#  'cargo',
#  'cbc',
#  'cdi',
#  'celebration',
#  'celerio',
#  'cgi',
#  'ciaz',
#  'city',
#  'civic',
#  'cj',
#  'cl',
#  'cla',
#  'class',
#  'classic',
#  'climber',
#  'club',
#  'clxi',
#  'cng',
#  'comfortline',
#  'corolla',
#  'corporate',
#  'country',
#  'cr',
#  'cr4',
#  'crde',
#  'crdi',
#  'creta',
#  'cross',
#  'crosspolo',
#  'cruiser',
#  'crysta',
#  'cs',
#  'cvt',
#  'cx',
#  'd2',
#  'd3',
#  'd4',
#  'd4dg',
#  'd4dj',
#  'd5',
#  'd6',
#  'd70',
#  'd75',
#  'dark',
#  'dci',
#  'dct',
#  'ddis',
#  'deca',
#  'delhi',
#  'delta',
#  'deluxe',
#  'design',
#  'dgl',
#  'di',
#  'dicor',
#  'diesel',
#  'discovery',
#  'dl',
#  'dle',
#  'dlg',
#  'dls',
#  'dlsx',
#  'dlx',
#  'dpe',
#  'dsg',
#  'dtec',
#  'dtech',
#  'dual',
#  'dualtone',
#  'duo',
#  'durasport',
#  'duratec',
#  'duratorq',
#  'duster',
#  'dv5',
#  'dx',
#  'dzire',
#  'e250',
#  'e270',
#  'e350',
#  'e4',
#  'e6',
#  'e8',
#  'ecoboost',
#  'ecosport',
#  'ecs',
#  'edition',
#  'eeco',
#  'efficiency',
#  'egls',
#  'eglx',
#  'elan',
#  'elantra',
#  'elegance',
#  'elite',
#  'els',
#  'elx',
#  'emax',
#  'endeavour',
#  'eon',
#  'era',
#  'erlx',
#  'ertiga',
#  'estate',
#  'esteem',
#  'estilo',
#  'etios',
#  'euro',
#  'euroiii',
#  'ev',
#  'evoque',
#  'evx',
#  'ex',
#  'excellence',
#  'exclusive',
#  'exective',
#  'executive',
#  'exeta',
#  'exi',
#  'explore',
#  'f7',
#  'facelift',
#  'fb',
#  'fe',
#  'fiesta',
#  'figo',
#  'flair',
#  'flat',
#  'fleet',
#  'fluence',
#  'ford',
#  'fortuner',
#  'freelander',
#  'freestyle',
#  'fs',
#  'fusion',
#  'fwd',
#  'g1',
#  'g2',
#  'g4',
#  'g6',
#  'g80',
#  'gamma',
#  'gateway',
#  'gd',
#  'gdi',
#  'genus',
#  'getaway',
#  'getz',
#  'gl',
#  'gla',
#  'glam',
#  'glanza',
#  'glc',
#  'gle',
#  'gls',
#  'glx',
#  'gold',
#  'grand',
#  'green',
#  'gs',
#  'gt',
#  'gti',
#  'gvs',
#  'gx',
#  'gxd',
#  'gxi',
#  'gypsy',
#  'h2',
#  'h4',
#  'h9',
#  'harrier',
#  'hexa',
#  'highline',
#  'honda',
#  'hse',
#  'htr',
#  'hurricane',
#  'hybrid',
#  'hyundai',
#  'i10',
#  'i20',
#  'idtec',
#  'ignis',
#  'ii',
#  'iii',
#  'ikon',
#  'immobiliser',
#  'indica',
#  'indigo',
#  'ingenio',
#  'innova',
#  'inscription',
#  'inspire',
#  'intelli',
#  'ipl',
#  'itech',
#  'iv',
#  'jaguar',
#  'jazz',
#  'jeep',
#  'jetta',
#  'js',
#  'k10',
#  'k2',
#  'k4',
#  'k6',
#  'k8',
#  'kappa',
#  'king',
#  'knightracer',
#  'koleos',
#  'kompressor',
#  'konekt',
#  'kuv',
#  'kwid',
#  'land',
#  'ldi',
#  'ldix',
#  'le',
#  'leather',
#  'limited',
#  'line',
#  'lite',
#  'litre',
#  'liva',
#  'lodgy',
#  'logan',
#  'lp',
#  'lpg',
#  'ls',
#  'lsi',
#  'luxury',
#  'lx',
#  'lxi',
#  'm2',
#  'm2di',
#  'm6',
#  'm8',
#  'magna',
#  'mahindra',
#  'manual',
#  'manza',
#  'marazzo',
#  'marshal',
#  'maruti',
#  'matrix',
#  'maxx',
#  'mdi',
#  'mercedes',
#  'mfalcon',
#  'mhawk',
#  'mhawk100',
#  'minor',
#  'mkii',
#  'ml',
#  'mm',
#  'mobilio',
#  'mpfi',
#  'mpi',
#  'ms',
#  'mt',
#  'multivan',
#  'n8',
#  'nan',
#  'nano',
#  'nav',
#  'new',
#  'nexon',
#  'nios',
#  'non',
#  'nrg',
#  'nuvosport',
#  'nxt',
#  'omni',
#  'opt',
#  'option',
#  'optional',
#  'p4',
#  'passat',
#  'petrol',
#  'pik',
#  'platinum',
#  'pleasure',
#  'plus',
#  'polo',
#  'portfolio',
#  'power',
#  'prado',
#  'premio',
#  'premium',
#  'presso',
#  'prestige',
#  'pride',
#  'primea',
#  'privilege',
#  'ps',
#  'pulse',
#  'pure',
#  'q3',
#  'q5',
#  'q7',
#  'quadrajet',
#  'quadrajet90',
#  'qualis',
#  'quanto',
#  'quattro',
#  'range',
#  'really',
#  'renault',
#  'revotorq',
#  'revotron',
#  'rexton',
#  'ritz',
#  'roof',
#  'rover',
#  'rs',
#  'rx5',
#  'rx7',
#  'rxe',
#  'rxl',
#  'rxs',
#  'rxt',
#  'rxz',
#  's10',
#  's11',
#  's2',
#  's3',
#  's4',
#  's5',
#  's6',
#  's60',
#  's7',
#  's8',
#  's90',
#  'safari',
#  'safety',
#  'safire',
#  'santa',
#  'santro',
#  'scala',
#  'scorpio',
#  'sdrive',
#  'sdrive20d',
#  'sdrive20i',
#  'se',
#  'seater',
#  'seats',
#  'sedan',
#  'select',
#  'series',
#  'sh',
#  'shvs',
#  'sigma',
#  'signature',
#  'silver',
#  'sle',
#  'slx',
#  'smart',
#  'smiles',
#  'soft',
#  'sonata',
#  'sp',
#  'spacio',
#  'special',
#  'speed',
#  'spl',
#  'sport',
#  'sportivo',
#  'sportline',
#  'sports',
#  'sportz',
#  'spotz',
#  'ssangyong',
#  'st',
#  'standard',
#  'star',
#  'std',
#  'stepway',
#  'stingray',
#  'storme',
#  'str',
#  'style',
#  'summum',
#  'sumo',
#  'sunroof',
#  'supro',
#  'sv',
#  'swift',
#  'sx',
#  'sx4',
#  'sxi',
#  't10',
#  't4',
#  't6',
#  't8',
#  'tata',
#  'tc',
#  'td4',
#  'tdci',
#  'tdi',
#  'tech',
#  'technology',
#  'terra',
#  'tfsi',
#  'thar',
#  'ti',
#  'tiago',
#  'tigor',
#  'titanium',
#  'tone',
#  'tour',
#  'toyota',
#  'transform',
#  'trd',
#  'trend',
#  'trendline',
#  'triber',
#  'tsi',
#  'tucson',
#  'turbo',
#  'turbomax',
#  'tuv',
#  'twist',
#  'uniq',
#  'v2',
#  'v4',
#  'v40',
#  'v6',
#  'varicor',
#  'vct',
#  'vd',
#  'vdi',
#  'vento',
#  'venture',
#  'venue',
#  'verito',
#  'verna',
#  'vgt',
#  'vibe',
#  'vista',
#  'vitara',
#  'viva',
#  'vl',
#  'vls',
#  'vlx',
#  'volkswagen',
#  'volvo',
#  'vs',
#  'vtec',
#  'vtech',
#  'vti',
#  'vtvt',
#  'vvt',
#  'vx',
#  'vxd',
#  'vxi',
#  'w10',
#  'w11',
#  'w4',
#  'w5',
#  'w6',
#  'w7',
#  'w8',
#  'w9',
#  'wagon',
#  'white',
#  'willys',
#  'windsong',
#  'winger',
#  'wizz',
#  'wo',
#  'world',
#  'wr',
#  'x1',
#  'x3',
#  'x4',
#  'x5',
#  'x6',
#  'x7',
#  'xc40',
#  'xc60',
#  'xc90',
#  'xcent',
#  'xdb',
#  'xdrive',
#  'xdrive20d',
#  'xdrive30d',
#  'xe',
#  'xenon',
#  'xf',
#  'xg',
#  'xi',
#  'xing',
#  'xk',
#  'xl',
#  'xl6',
#  'xline',
#  'xlt',
#  'xm',
#  'xms',
#  'xo',
#  'xp',
#  'xs',
#  'xt',
#  'xta',
#  'xuv300',
#  'xuv500',
#  'xxi',
#  'xylo',
#  'xz',
#  'xza',
#  'yaris',
#  'zdi',
#  'zen',
#  'zest',
#  'zeta',
#  'zipdrive',
#  'zipplus',
#  'zlx',
#  'zx',
#  'zxi']

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
similarity=cosine_similarity(vectors)

# %%
def recommand():
    print(df['company'].unique())
    obj1=input("Enter company:")
    print(df[df['company']==obj1]['Model name'].unique())
    obj2=input("Enter Model Name:")
    print(df[df['Model name']==obj2]['fuel'].unique())
    obj3=input("Enter Fuel Type:")
    print(df[df['Model name']==obj2]['new engine'].unique())
    obj4=int(input("Enter engine:"))
    car_index=df[(df['company']==obj1) & (df['Model name']==obj2)&(df['fuel']==obj3)&(finall['new engine']==obj4)].index[0]
    k=similarity[car_index]
    lst=sorted(list(enumerate(k)),reverse=True,key=lambda x:x[1])[1:]
    lst1 = list(enumerate(df['Insurance'].values.tolist()))
    lst2= []
    for i in lst:
        for j in lst1:
            if i[0]==j[0]:
                if j[1] not in lst2:
                    lst2.append(j[1])
  
    
    print("Your Insurance Plans")
    for i in lst2[0:5]:
        print(i)
    print("If you want more options I can Help You.Please Enter Y for More plans and N  for stop.")
    a = input("Enter Your choice:").lower()
    if a=='y':
        for i in lst2[5:10]:
            print(i)
    else:
        print("Thank you")

# %%
recommand()
# Out:
# ['Maruti' 'Honda' 'Hyundai' 'Toyota' 'Ford' 'Renault' 'Mahindra' 'Tata'
#  'Mercedes-Benz' 'Audi' 'Volkswagen' 'BMW' 'Jaguar' 'Land' 'Volvo']
# Enter company:Audi
# ['Audi A6 2.0 TDI Technology' 'Audi A6 2.0 TDI Design Edition'
#  'Audi Q5 35TDI Premium Plus' 'Audi Q7 35 TDI Quattro Premium'
#  'Audi A4 2.0 TDI' 'Audi Q5 2.0 TDI'
#  'Audi Q3 2.0 TDI Quattro Premium Plus' 'Audi A3 35 TDI Premium Plus'
#  'Audi Q5 3.0 TDI Quattro' 'Audi Q7 3.0 TDI Quattro'
#  'Audi Q7 3.0 TDI Quattro Premium Plus'
#  'Audi Q3 35 TDI Quattro Premium Plus' 'Audi A4 35 TDI Premium Plus'
#  'Audi A4 1.8 TFSI' 'Audi Q5 45 TDI quattro Technology'
#  'Audi A6 35 TFSI Matrix' 'Audi A4 2.0 TDI 177 Bhp Premium Plus'
#  'Audi Q3 35 TDI Quattro Technology' 'Audi A6 2.0 TDI Premium Plus'
#  'Audi A6 2.0 TDI' 'Audi A3 40 TFSI Premium']
# Enter Model Name:Audi A6 2.0 TDI Design Edition
# ['diesel']
# Enter Fuel Type:diesel
# [1968]
# Enter engine:1968
# Your Insurance Plans
# Comapany Name:Acko,Policy Plan:4578
# Comapany Name:ICICI Lombord,Policy Plan:2000000
# Comapany Name:Go Digit,Policy Plan:4000
# Comapany Name:Magma HDI,Policy Plan:3259
# Comapany Name:HDFC Argo,Policy Plan:8500
# If you want more options I can Help You.Please Enter Y for More plans and N  for stop.
# Enter Your choice:Y
# Comapany Name:Ako,Policy Plan:4578
# Comapany Name:Go Digit,Policy Plan:6000
# Comapany Name:Go Digit,Policy Plan:4300
# Comapany Name:Magma HDI,Policy Plan:3600
# Comapany Name:Reliance General,Policy Plan:1400000
